# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditi16324/Calculator/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# List Of shopping cart

# %%
L1 = [ "oil" , "wheat" , "milk"]
print(L1)
# Out:
# ['oil', 'wheat', 'milk']

# %% [markdown]
# lIST OF ROLL NUMBERS

# %%
L1 = [ 101, 102, 103, 104, 105]
print("The roll no are" , L1)
print(type(L1))
# Out:
# The roll no are [101, 102, 103, 104, 105]
# <class 'list'>

# %% [markdown]
# Its not important to have same data in the list

# %%
List1 = [ "text", 4.5 , 78 , [45,56,"text"]]
List1

['text'], 4.5 , 78, [45, 56, 'text']
# Out:
# (['text'], 4.5, 78, [45, 56, 'text'])

# %% [markdown]
# Add on a specific location

# %%
L1 = [ 101,102,103,104,105 ]
print(L1)

[ 101,102,103,104,105]
# Out:
# [101, 102, 103, 104, 105]
# [101, 102, 103, 104, 105]

# %%
# append - its not in the end
# when we want to insert on a pecific location
# / we use insert

L1.insert(2 , 108)
print(L1)
# Out:
# [101, 102, 108, 103, 104, 105]

# %% [markdown]
# Delete Items

# %% [markdown]
# SSE Shoppuing Cart

# %%
print( "WELCOME TO SSE MART")
Your_cart = [ "shoes", "tv remote" , "dress" , "chips", "perfume"]

print("your current list")
print(Your_cart)

add_item = "hair_gel"
Your_cart.append(add_item)

print( "="*40)
print("your current list")
print(Your_cart)

delete_item = "tv remote"
Your_cart.remove(delete_item)
print( "="*40)
print(Your_cart)
# Out:
# WELCOME TO SSE MART
# your current list
# ['shoes', 'tv remote', 'dress', 'chips', 'perfume']
# ...
# your current list
# ['shoes', 'tv remote', 'dress', 'chips', 'perfume', 'hair_gel']
# ...
# ['shoes', 'dress', 'chips', 'perfume', 'hair_gel']
